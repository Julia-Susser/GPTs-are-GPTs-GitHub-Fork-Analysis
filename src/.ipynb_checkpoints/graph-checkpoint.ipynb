# %%
import requests
import pandas as pd
import seaborn as sns
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import numpy as np


dfStargazers = pd.read_csv("../inputs/huggingface-transformers.csv")

# %%
dfStargazers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   login                40000 non-null  object
#  1   id                   40000 non-null  int64
#  2   node_id              40000 non-null  object
#  3   avatar_url           40000 non-null  object
#  4   gravatar_id          0 non-null      float64
#  5   url                  40000 non-null  object
#  6   html_url             40000 non-null  object
#  7   followers_url        40000 non-null  object
#  8   following_url        40000 non-null  object
#  9   gists_url            40000 non-null  object
#  10  starred_url          40000 non-null  object
#  11  subscriptions_url    40000 non-null  object
#  12  organizations_url    40000 non-null  object
#  13  repos_url            40000 non-null  object
#  14  events_url           40000 non-null  object
#  15  received_events_url  40000 non-null  object
#  16  type                 40000 non-null  object
#  17  site_admin           40000 non-null  bool
#  18  starred_at           40000 non-null  object
# dtypes: bool(1), float64(1), int64(1), object(16)
# memory usage: 5.5+ MB

# %%
dfStargazers['starred_at'] = pd.to_datetime(dfStargazers['starred_at'])

# %%
dfStargazers["year-mo"] = dfStargazers["starred_at"].dt.to_period('M')
data = dfStargazers.groupby("year-mo")["id"].count().reset_index()
data["year-mo"] = data["year-mo"].dt.to_timestamp()
data
# Out:
# /opt/homebrew/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:1162: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   warnings.warn(
#       year-mo    id
# 0  2018-11-01  1591
# 1  2018-12-01   576
# 2  2019-01-01   528
# 3  2019-02-01   980
# 4  2019-03-01   773
# 5  2019-04-01   698
# 6  2019-05-01   725
# 7  2019-06-01   831
# 8  2019-07-01  2479
# 9  2019-08-01  1350
# 10 2019-09-01  2613
# 11 2019-10-01  1767
# 12 2019-11-01  1726
# 13 2019-12-01  1880
# 14 2020-01-01  1521
# 15 2020-02-01  1313
# 16 2020-03-01  1517
# 17 2020-04-01  1527
# 18 2020-05-01  2071
# 19 2020-06-01  1824
# 20 2020-07-01  1805
# 21 2020-08-01  1378
# 22 2020-09-01  1306
# 23 2020-10-01  1535
# 24 2020-11-01  1468
# 25 2020-12-01  1337
# 26 2021-01-01  1474
# 27 2021-02-01  1287
# 28 2021-03-01   120

# %%
sns.lineplot(data=data, x="year-mo", y="id")
plt.show()
# Out:
#                  login        id               node_id  \
# 0               kashif      8100      MDQ6VXNlcjgxMDA=
# 1              ink-pad  25939172  MDQ6VXNlcjI1OTM5MTcy
# 2             netankit    953463  MDQ6VXNlcjk1MzQ2Mw==
# 3             julien-c    326577  MDQ6VXNlcjMyNjU3Nw==
# 4      geraldinelemeur  37600826  MDQ6VXNlcjM3NjAwODI2
# ...                ...       ...                   ...
# 39995            mxiao   4312882  MDQ6VXNlcjQzMTI4ODI=
# 39996          lvse301  76778653  MDQ6VXNlcjc2Nzc4NjUz
# 39997         sairoopb  47033373  MDQ6VXNlcjQ3MDMzMzcz
# 39998             m13m   7526000  MDQ6VXNlcjc1MjYwMDA=
# 39999        Damon-wyg  22114187  MDQ6VXNlcjIyMTE0MTg3
#
#                                               avatar_url  gravatar_id  \
# 0       https://avatars.githubusercontent.com/u/8100?v=4          NaN
# 1      https://avatars.githubusercontent.com/u/259391...          NaN
# 2      https://avatars.githubusercontent.com/u/953463...          NaN
# 3      https://avatars.githubusercontent.com/u/326577...          NaN
# 4      https://avatars.githubusercontent.com/u/376008...          NaN
# ...                                                  ...          ...
# 39995  https://avatars.githubusercontent.com/u/431288...          NaN
# 39996  https://avatars.githubusercontent.com/u/767786...          NaN
# 39997  https://avatars.githubusercontent.com/u/470333...          NaN
# 39998  https://avatars.githubusercontent.com/u/752600...          NaN
# 39999  https://avatars.githubusercontent.com/u/221141...          NaN
#
#                                                 url  \
# 0               https://api.github.com/users/kashif
# 1              https://api.github.com/users/ink-pad
# 2             https://api.github.com/users/netankit
# 3             https://api.github.com/users/julien-c
# 4      https://api.github.com/users/geraldinelemeur
# ...                                             ...
# 39995            https://api.github.com/users/mxiao
# 39996          https://api.github.com/users/lvse301
# 39997         https://api.github.com/users/sairoopb
# 39998             https://api.github.com/users/m13m
# 39999        https://api.github.com/users/Damon-wyg
#
#                                  html_url  \
# 0               https://github.com/kashif
# 1              https://github.com/ink-pad
# 2             https://github.com/netankit
# 3             https://github.com/julien-c
# 4      https://github.com/geraldinelemeur
# ...                                   ...
# 39995            https://github.com/mxiao
# 39996          https://github.com/lvse301
# 39997         https://github.com/sairoopb
# 39998             https://github.com/m13m
# 39999        https://github.com/Damon-wyg
#
#                                            followers_url  \
# 0          https://api.github.com/users/kashif/followers
# 1         https://api.github.com/users/ink-pad/followers
# 2        https://api.github.com/users/netankit/followers
# 3        https://api.github.com/users/julien-c/followers
# 4      https://api.github.com/users/geraldinelemeur/f...
# ...                                                  ...
# 39995       https://api.github.com/users/mxiao/followers
# 39996     https://api.github.com/users/lvse301/followers
# 39997    https://api.github.com/users/sairoopb/followers
# 39998        https://api.github.com/users/m13m/followers
# 39999   https://api.github.com/users/Damon-wyg/followers
#
#                                            following_url  \
# 0      https://api.github.com/users/kashif/following{...
# 1      https://api.github.com/users/ink-pad/following...
# 2      https://api.github.com/users/netankit/followin...
# 3      https://api.github.com/users/julien-c/followin...
# 4      https://api.github.com/users/geraldinelemeur/f...
# ...                                                  ...
# 39995  https://api.github.com/users/mxiao/following{/...
# 39996  https://api.github.com/users/lvse301/following...
# 39997  https://api.github.com/users/sairoopb/followin...
# 39998  https://api.github.com/users/m13m/following{/o...
# 39999  https://api.github.com/users/Damon-wyg/followi...
#
#                                                gists_url  \
# 0      https://api.github.com/users/kashif/gists{/gis...
# 1      https://api.github.com/users/ink-pad/gists{/gi...
# 2      https://api.github.com/users/netankit/gists{/g...
# 3      https://api.github.com/users/julien-c/gists{/g...
# 4      https://api.github.com/users/geraldinelemeur/g...
# ...                                                  ...
# 39995  https://api.github.com/users/mxiao/gists{/gist...
# 39996  https://api.github.com/users/lvse301/gists{/gi...
# 39997  https://api.github.com/users/sairoopb/gists{/g...
# 39998  https://api.github.com/users/m13m/gists{/gist_id}
# 39999  https://api.github.com/users/Damon-wyg/gists{/...
#
#                                              starred_url  \
# 0      https://api.github.com/users/kashif/starred{/o...
# 1      https://api.github.com/users/ink-pad/starred{/...
# 2      https://api.github.com/users/netankit/starred{...
# 3      https://api.github.com/users/julien-c/starred{...
# 4      https://api.github.com/users/geraldinelemeur/s...
# ...                                                  ...
# 39995  https://api.github.com/users/mxiao/starred{/ow...
# 39996  https://api.github.com/users/lvse301/starred{/...
# 39997  https://api.github.com/users/sairoopb/starred{...
# 39998  https://api.github.com/users/m13m/starred{/own...
# 39999  https://api.github.com/users/Damon-wyg/starred...
#
#                                        subscriptions_url  \
# 0      https://api.github.com/users/kashif/subscriptions
# 1      https://api.github.com/users/ink-pad/subscript...
# 2      https://api.github.com/users/netankit/subscrip...
# 3      https://api.github.com/users/julien-c/subscrip...
# 4      https://api.github.com/users/geraldinelemeur/s...
# ...                                                  ...
# 39995   https://api.github.com/users/mxiao/subscriptions
# 39996  https://api.github.com/users/lvse301/subscript...
# 39997  https://api.github.com/users/sairoopb/subscrip...
# 39998    https://api.github.com/users/m13m/subscriptions
# 39999  https://api.github.com/users/Damon-wyg/subscri...
#
#                                        organizations_url  \
# 0               https://api.github.com/users/kashif/orgs
# 1              https://api.github.com/users/ink-pad/orgs
# 2             https://api.github.com/users/netankit/orgs
# 3             https://api.github.com/users/julien-c/orgs
# 4      https://api.github.com/users/geraldinelemeur/orgs
# ...                                                  ...
# 39995            https://api.github.com/users/mxiao/orgs
# 39996          https://api.github.com/users/lvse301/orgs
# 39997         https://api.github.com/users/sairoopb/orgs
# 39998             https://api.github.com/users/m13m/orgs
# 39999        https://api.github.com/users/Damon-wyg/orgs
#
#                                                repos_url  \
# 0              https://api.github.com/users/kashif/repos
# 1             https://api.github.com/users/ink-pad/repos
# 2            https://api.github.com/users/netankit/repos
# 3            https://api.github.com/users/julien-c/repos
# 4      https://api.github.com/users/geraldinelemeur/r...
# ...                                                  ...
# 39995           https://api.github.com/users/mxiao/repos
# 39996         https://api.github.com/users/lvse301/repos
# 39997        https://api.github.com/users/sairoopb/repos
# 39998            https://api.github.com/users/m13m/repos
# 39999       https://api.github.com/users/Damon-wyg/repos
#
#                                               events_url  \
# 0      https://api.github.com/users/kashif/events{/pr...
# 1      https://api.github.com/users/ink-pad/events{/p...
# 2      https://api.github.com/users/netankit/events{/...
# 3      https://api.github.com/users/julien-c/events{/...
# 4      https://api.github.com/users/geraldinelemeur/e...
# ...                                                  ...
# 39995  https://api.github.com/users/mxiao/events{/pri...
# 39996  https://api.github.com/users/lvse301/events{/p...
# 39997  https://api.github.com/users/sairoopb/events{/...
# 39998  https://api.github.com/users/m13m/events{/priv...
# 39999  https://api.github.com/users/Damon-wyg/events{...
#
#                                      received_events_url  type  site_admin  \
# 0      https://api.github.com/users/kashif/received_e...  User       False
# 1      https://api.github.com/users/ink-pad/received_...  User       False
# 2      https://api.github.com/users/netankit/received...  User       False
# 3      https://api.github.com/users/julien-c/received...  User       False
# 4      https://api.github.com/users/geraldinelemeur/r...  User       False
# ...                                                  ...   ...         ...
# 39995  https://api.github.com/users/mxiao/received_ev...  User       False
# 39996  https://api.github.com/users/lvse301/received_...  User       False
# 39997  https://api.github.com/users/sairoopb/received...  User       False
# 39998  https://api.github.com/users/m13m/received_events  User       False
# 39999  https://api.github.com/users/Damon-wyg/receive...  User       False
#
#                starred_at  year-mo
# 0     2018-11-05 15:19:44  2018-11
# 1     2018-11-05 15:20:04  2018-11
# 2     2018-11-05 15:20:35  2018-11
# 3     2018-11-05 15:29:07  2018-11
# 4     2018-11-05 15:30:03  2018-11
# ...                   ...      ...
# 39995 2021-02-21 08:47:33  2021-02
# 39996 2021-02-21 10:35:09  2021-02
# 39997 2021-02-21 12:20:40  2021-02
# 39998 2021-02-21 13:46:18  2021-02
# 39999 2021-02-21 13:53:04  2021-02
#
# [40000 rows x 20 columns]

# %%
df = pd.read_csv("../inputs/repos.csv")

# %%
len(df)-len(df.drop_duplicates())
# Out:
# 2039
